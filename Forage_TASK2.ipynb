# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **CONTENT DATAFRAME**

# %%
content=pd.read_csv("Content.csv",index_col=0)
content
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
content=content.drop(columns=['URL','User ID'])

# %%
content.rename(columns={'Type':'Content Type'},inplace=True)

# %%
content
# Out:
#                                Content ID Content Type         Category
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2        photo         Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo   healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f        photo   healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6        photo       technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180        video             food
# ..                                    ...          ...              ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb        video  public speaking
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c          GIF       technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b        audio         veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7          GIF          culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56        audio       technology
#
# [1000 rows x 3 columns]

# %%
content.isnull().sum()
# Out:
# Content ID      0
# Content Type    0
# Category        0
# dtype: int64

# %%
content.dtypes
# Out:
# Content ID      object
# Content Type    object
# Category        object
# dtype: object

# %% [markdown]
# **REACTION TYPES DATAFRAME**

# %%
rtype=pd.read_csv('ReactionTypes.csv',index_col=0)
rtype
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
rtype.rename(columns={'Type':'Reaction Type'},inplace=True)

# %%
rtype
# Out:
#    Reaction Type Sentiment  Score
# 0          heart  positive     60
# 1           want  positive     70
# 2        disgust  negative      0
# 3           hate  negative      5
# 4     interested  positive     30
# 5    indifferent   neutral     20
# 6           love  positive     65
# 7     super love  positive     75
# 8        cherish  positive     70
# 9          adore  positive     72
# 10          like  positive     50
# 11       dislike  negative     10
# 12     intrigued  positive     45
# 13       peeking   neutral     35
# 14        scared  negative     15
# 15       worried  negative     12

# %%
rtype.dtypes
# Out:
# Reaction Type    object
# Sentiment        object
# Score             int64
# dtype: object

# %%
reaction=pd.read_csv('Reactions.csv',index_col=0)
reaction
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# ...

# %%
reaction=reaction.drop(columns='User ID')

# %%
reaction.isna().sum()
# Out:
# Content ID      0
# Type          980
# Datetime        0
# dtype: int64

# %%
reaction.dropna(subset='Type',inplace=True)

# %%
reaction.isna().sum()
# Out:
# Content ID    0
# Type          0
# Datetime      0
# dtype: int64

# %%
reaction.dtypes
# Out:
# Content ID    object
# Type          object
# Datetime      object
# dtype: object

# %%
reaction.rename(columns={'Type':'Reaction Type'},inplace=True)

# %%
reaction
# Out:
#                                  Content ID Reaction Type             Datetime
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2020-11-07 09:43:50
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  2021-06-17 12:22:51
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  2021-04-18 05:13:58
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  2021-01-06 19:13:01
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  2020-08-23 12:25:58
# ...                                     ...           ...                  ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike  2020-06-27 09:46:48
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued  2021-02-16 17:17:02
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56    interested  2020-09-12 03:54:58
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56       worried  2020-11-04 20:08:31
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish  2021-01-04 04:55:11
#
# ...

# %% [markdown]
# **MERGING ALL THE DATAFRAMES WITH REACTION AS BASE DATAFRAME**

# %%
final_df=reaction.merge(content,on='Content ID',how='left')
final_df=final_df.merge(rtype,on='Reaction Type',how='left')

# %%
final_df
# Out:
#                                  Content ID Reaction Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...                                     ...           ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime Content Type    Category Sentiment  Score
# 0      2020-11-07 09:43:50        photo    Studying  negative      0
# 1      2021-06-17 12:22:51        photo    Studying  negative     10
# ...

# %%
final_df.isna().sum()
# Out:
# Content ID       0
# Reaction Type    0
# Datetime         0
# Content Type     0
# Category         0
# Sentiment        0
# Score            0
# dtype: int64

# %% [markdown]
# **FINDING TOP 5 CATEGORIES**

# %%
totalscore = final_df.groupby('Category')['Score'].sum()
totalscore
# Out:
# Category
# "animals"             1694
# "cooking"              774
# "culture"             2037
# "dogs"                1763
# "food"                  50
# "public speaking"      979
# "science"              506
# "soccer"              2468
# "studying"             546
# "technology"          1049
# "veganism"            1129
# Animals               3723
# Culture               1627
# Education             1395
# Fitness               5488
# Food                  3504
# Healthy Eating         272
# Public Speaking       1336
# Science               4619
# Soccer                2631
# Studying              1341
# Technology             217
# Travel                1092
# Veganism               644
# animals              69548
# cooking              63982
# culture              62915
# dogs                 50748
# education            56041
# fitness              49835
# food                 63122
# healthy eating       69067
# public speaking      46949
# science              66043
# ...

# %%
top5=totalscore.nlargest(5)
print(top5,'\n')
top5_category=top5.index
# Out:
# Category
# animals           69548
# healthy eating    69067
# technology        67472
# science           66043
# cooking           63982
# Name: Score, dtype: int64

# %%
result=final_df[final_df['Category'].isin(top5_category)]
result
# Out:
#                                  Content ID Reaction Type  \
# 45     9f737e0a-3cdd-4d29-9d24-753f4e3be810       dislike
# 46     9f737e0a-3cdd-4d29-9d24-753f4e3be810     intrigued
# 47     9f737e0a-3cdd-4d29-9d24-753f4e3be810       peeking
# 48     9f737e0a-3cdd-4d29-9d24-753f4e3be810        scared
# 49     9f737e0a-3cdd-4d29-9d24-753f4e3be810          hate
# ...                                     ...           ...
# 24568  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 24569  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 24570  75d6b589-7fae-4a6d-b0d0-752845150e56    interested
# 24571  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 24572  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime Content Type        Category Sentiment  Score
# 45     2020-06-25 17:01:58        photo  healthy eating  negative     10
# 46     2020-09-13 00:11:50        photo  healthy eating  positive     45
# ...

# %%
result.isna().sum()
# Out:
# Content ID       0
# Reaction Type    0
# Datetime         0
# Content Type     0
# Category         0
# Sentiment        0
# Score            0
# dtype: int64

# %%
result.to_csv('End Result')
